# %% [markdown]
# ###My First iPython Notebook!
#
# I can make a list!
#
# - one
# - two
# - three
#
#
#
# I can write in  **bold** or *italics*
#
# And I can write LaTex
#
# $$\sin{x^2}$$
#
# I can write `code`
#
# or code blocks
#
#     This is a code block

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
pd.Series?
pd.DataFrame?

# %% [markdown]
# ###Create my first DataFrame!

# %%
# Make two lists, one of names, one of births

names = [
"matt",
"Raphael",
"Christopher",
"James",
"Carlos",
"Scott",
"Ellery",
"Vrushank",
"dylan"]

births = [
12022,
98,
14755,
26777,
1581,
6940,
1,
1,
3400
]

# %%
babydataset = zip(names,births)
babydataset
# Out:
# [('matt', 12022),
#  ('Raphael', 98),
#  ('Christopher', 14755),
#  ('James', 26777),
#  ('Carlos', 1581),
#  ('Scott', 6940),
#  ('Ellery', 1),
#  ('Vrushank', 1),
#  ('dylan', 3400)]

# %%
df = pd.DataFrame(data= babydataset, columns = ['Names','Births'])
df
# Out:
#          Names  Births
# 0         matt   12022
# 1      Raphael      98
# 2  Christopher   14755
# 3        James   26777
# 4       Carlos    1581
# 5        Scott    6940
# 6       Ellery       1
# 7     Vrushank       1
# 8        dylan    3400
#
# [9 rows x 2 columns]

# %%
df2 = pd.read_csv("/Users/matthewgee/Downloads/baby_names.csv")
df2.describe()
# Out:
#               year     numbirths
# count     9.000000      9.000000
# mean   1984.888889   7286.111111
# std      23.213382   9108.322217
# min    1940.000000      1.000000
# 25%    1979.000000     98.000000
# 50%    1989.000000   3400.000000
# 75%    2005.000000  12022.000000
# max    2012.000000  26777.000000
#
# [8 rows x 2 columns]

# %%
df2.plot()

# %%
df2
# Out:
#           name  year  numbirths
# 0         matt  1981      12022
# 1      Raphael  2012         98
# 2  Christopher  1979      14755
# 3        James  1940      26777
# 4       Carlos  2005       1581
# 5        Scott  1960       6940
# 6       Ellery  1989          1
# 7     Vrushank  1993          1
# 8        dylan  2005       3400
#
# [9 rows x 3 columns]

# %%
df2_sorted = df2.sort(['year','numbirths'], ascending=[0,0])
df2_sorted
# Out:
#           name  year  numbirths
# 1      Raphael  2012         98
# 8        dylan  2005       3400
# 4       Carlos  2005       1581
# 7     Vrushank  1993          1
# 6       Ellery  1989          1
# 0         matt  1981      12022
# 2  Christopher  1979      14755
# 5        Scott  1960       6940
# 3        James  1940      26777
#
# [9 rows x 3 columns]
